# %%
! pip install numpy pandas ray[tune] scikit-learn torch

# %%
import numpy as np
import pandas as pd
import ray
from ray import tune
from sklearn.model_selection import KFold
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

# %%
train_df = pd.read_csv('../data/train.csv')
test_df = pd.read_csv('../data/test.csv')

all_user_ids = np.unique(np.concatenate([train_df['user_id'].unique(), test_df['user_id'].unique()]))
all_user_ids.sort()
all_book_ids = np.unique(np.concatenate([train_df['book_id'].unique(), test_df['book_id'].unique()]))
all_book_ids.sort()

# %%
user_id_to_index = {user_id: i for i, user_id in enumerate(all_user_ids)}
book_id_to_index = {book_id: i for i, book_id in enumerate(all_book_ids)}

# %%
num_users = len(all_user_ids)
num_items = len(all_book_ids)

train_data_triplets = []
for index, row in train_df.iterrows():
    user_index = user_id_to_index[row['user_id']]
    book_index = book_id_to_index[row['book_id']]
    rating = row['rating']
    train_data_triplets.append((user_index, book_index, rating))

test_data_triplets = []
for index, row in test_df.iterrows():
    user_index = user_id_to_index[row['user_id']]
    book_index = book_id_to_index[row['book_id']]
    test_data_triplets.append((user_index, book_index))

# %%
train_data_array = np.array(train_data_triplets)
train_data_array

# %%
class RatingDataset(Dataset):
    def __init__(self, triplets):
        self.triplets = triplets

    def __len__(self):
        return len(self.triplets)

    def __getitem__(self, idx):
        u, i, r = self.triplets[idx]
        return torch.tensor(u, dtype=torch.long), torch.tensor(i, dtype=torch.long), torch.tensor(r, dtype=torch.float)

# %%
class NeuMF(nn.Module):
    def __init__(self, num_users, num_items, mf_dim=8, mlp_layers=[16, 8], dropout=0.2):
        super(NeuMF, self).__init__()

        self.user_embedding_gmf = nn.Embedding(num_users, mf_dim)
        self.item_embedding_gmf = nn.Embedding(num_items, mf_dim)

        self.user_embedding_mlp = nn.Embedding(num_users, mlp_layers[0] // 2)
        self.item_embedding_mlp = nn.Embedding(num_items, mlp_layers[0] // 2)

        mlp_modules = []
        input_size = mlp_layers[0]
        for layer_size in mlp_layers[1:]:
            mlp_modules.append(nn.Linear(input_size, layer_size))
            mlp_modules.append(nn.ReLU())
            mlp_modules.append(nn.Dropout(dropout))  # Add Dropout layer
            input_size = layer_size
        self.mlp = nn.Sequential(*mlp_modules)

        predict_size = mf_dim + mlp_layers[-1]
        self.predict_layer = nn.Linear(predict_size, 1)

        nn.init.normal_(self.user_embedding_gmf.weight, std=0.01)
        nn.init.normal_(self.item_embedding_gmf.weight, std=0.01)
        nn.init.normal_(self.user_embedding_mlp.weight, std=0.01)
        nn.init.normal_(self.item_embedding_mlp.weight, std=0.01)

    def forward(self, user, item):
        gmf_u = self.user_embedding_gmf(user)
        gmf_i = self.item_embedding_gmf(item)
        gmf_out = gmf_u * gmf_i

        mlp_u = self.user_embedding_mlp(user)
        mlp_i = self.item_embedding_mlp(item)
        mlp_cat = torch.cat([mlp_u, mlp_i], dim=-1)
        mlp_out = self.mlp(mlp_cat)

        cat_out = torch.cat([gmf_out, mlp_out], dim=-1)
        pred = self.predict_layer(cat_out)
        return pred.squeeze()

# %%
def train_one_fold(
    train_data,
    val_data,
    num_users,
    num_items,
    mf_dim,
    mlp_layers,
    dropout,
    lr,
    weight_decay,
    batch_size,
    epochs=10,
    patience=3,
):
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"using {device}")
    model = NeuMF(
        num_users, num_items, mf_dim=mf_dim, mlp_layers=mlp_layers, dropout=dropout
    ).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)
    loss_fn = nn.MSELoss()

    train_dataset = RatingDataset(train_data)
    val_dataset = RatingDataset(val_data)

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

    best_val_rmse = float("inf")
    epochs_no_improve = 0

    for epoch in range(epochs):
        model.train()
        for u, i, r in train_loader:
            u, i, r = u.to(device), i.to(device), r.to(device)
            optimizer.zero_grad()
            pred = model(u, i)
            loss = loss_fn(pred, r)
            loss.backward()
            optimizer.step()

        model.eval()
        val_sse = 0.0
        val_samples = 0
        with torch.no_grad():
            for u, i, r in val_loader:
                u, i, r = u.to(device), i.to(device), r.to(device)
                pred = model(u, i)
                val_sse += ((pred - r) ** 2).sum().item()
                val_samples += len(r)
        val_mse = val_sse / val_samples
        val_rmse = val_mse**0.5

        if val_rmse < best_val_rmse:
            best_val_rmse = val_rmse
            epochs_no_improve = 0
        else:
            epochs_no_improve += 1
            if epochs_no_improve >= patience:
                break

    return best_val_rmse


def k_fold_cv(
    all_data,
    num_users,
    num_items,
    mf_dim,
    mlp_layers,
    dropout,
    lr,
    weight_decay,
    batch_size,
    k,
    epochs,
    patience,
):
    kf = KFold(n_splits=k, shuffle=True, random_state=42)
    fold_rmse_list = []
    for train_idx, val_idx in kf.split(all_data):
        train_data = all_data[train_idx]
        val_data = all_data[val_idx]
        fold_rmse = train_one_fold(
            train_data,
            val_data,
            num_users,
            num_items,
            mf_dim,
            mlp_layers,
            dropout,
            lr,
            weight_decay,
            batch_size,
            epochs,
            patience,
        )
        fold_rmse_list.append(fold_rmse)
        break # Only train one fold for now
    return np.mean(fold_rmse_list), np.std(fold_rmse_list)


def train_with_k_fold(config):
    mf_dim = config["mf_dim"]
    mlp_layers = config["mlp_layers"]
    dropout = config["dropout"]
    lr = config["lr"]
    weight_decay = config["weight_decay"]
    batch_size = config["batch_size"]

    val_rmse, std = k_fold_cv(
        train_data_array,
        num_users,
        num_items,
        mf_dim,
        mlp_layers,
        dropout,
        lr,
        weight_decay,
        batch_size,
        k=5,
        epochs=200,
        patience=5,
    )

    return {"val_rmse": val_rmse, "std": std}

# %%
ray.init()

search_space = {
    "mf_dim": tune.grid_search([4, 8, 16]),
    "mlp_layers": tune.grid_search([[8, 4], [16, 4], [16, 8], [32, 16, 4], [32, 16, 8]]),
    "dropout": tune.grid_search([0.0, 0.1, 0.15, 0.20, 0.25, 0.30]),
    "lr": tune.grid_search([1e-2, 5e-3, 1e-3]),
    "weight_decay": tune.grid_search([1e-3, 1e-4, 1e-5]),
    "batch_size": tune.grid_search([512, 1024, 2048, 4096]),
}

analysis = tune.run(
    train_with_k_fold,
    config=search_space,
    metric="val_rmse",
    mode="min",
    resources_per_trial={"cpu": 1, "gpu": 0},
)

best_config = analysis.get_best_config(metric="val_rmse", mode="min")
print("Best config found:", best_config)

df = analysis.results_df
df.to_csv("new_mf_tune_results.csv")

ray.shutdown()
# Out:
# 2024-12-10 18:27:41,574	INFO tune.py:1041 -- Total run time: 91.45 seconds (80.44 seconds for the tuning loop).
# 2024-12-10 18:27:41,579	WARNING tune.py:1056 -- Experiment has been interrupted, but the most recent state was saved.
# Resume experiment with: tune.run(..., resume=True)
# 2024-12-10 18:27:41,634	WARNING experiment_analysis.py:180 -- Failed to fetch metrics for 200 trial(s):
# - train_with_k_fold_d8d1b_00022: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00022: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00022_22_batch_size=2048,dropout=0.3000,lr=0.0100,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00023: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00023: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00023_23_batch_size=4096,dropout=0.3000,lr=0.0100,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00024: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00024: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00024_24_batch_size=512,dropout=0.0000,lr=0.0050,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00025: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00025: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00025_25_batch_size=1024,dropout=0.0000,lr=0.0050,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00026: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00026: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00026_26_batch_size=2048,dropout=0.0000,lr=0.0050,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00027: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00027: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00027_27_batch_size=4096,dropout=0.0000,lr=0.0050,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00028: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00028: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00028_28_batch_size=512,dropout=0.1000,lr=0.0050,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00029: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00029: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00029_29_batch_size=1024,dropout=0.1000,lr=0.0050,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00030: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00030: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00030_30_batch_size=2048,dropout=0.1000,lr=0.0050,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00031: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00031: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00031_31_batch_size=4096,dropout=0.1000,lr=0.0050,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00032: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00032: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00032_32_batch_size=512,dropout=0.1500,lr=0.0050,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00033: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00033: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00033_33_batch_size=1024,dropout=0.1500,lr=0.0050,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00034: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00034: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00034_34_batch_size=2048,dropout=0.1500,lr=0.0050,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00035: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00035: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00035_35_batch_size=4096,dropout=0.1500,lr=0.0050,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00036: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00036: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00036_36_batch_size=512,dropout=0.2000,lr=0.0050,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00037: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00037: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00037_37_batch_size=1024,dropout=0.2000,lr=0.0050,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00038: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00038: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00038_38_batch_size=2048,dropout=0.2000,lr=0.0050,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00039: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00039: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00039_39_batch_size=4096,dropout=0.2000,lr=0.0050,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00040: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00040: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00040_40_batch_size=512,dropout=0.2500,lr=0.0050,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00041: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00041: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00041_41_batch_size=1024,dropout=0.2500,lr=0.0050,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00042: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00042: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00042_42_batch_size=2048,dropout=0.2500,lr=0.0050,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00043: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00043: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00043_43_batch_size=4096,dropout=0.2500,lr=0.0050,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00044: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00044: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00044_44_batch_size=512,dropout=0.3000,lr=0.0050,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00045: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00045: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00045_45_batch_size=1024,dropout=0.3000,lr=0.0050,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00046: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00046: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00046_46_batch_size=2048,dropout=0.3000,lr=0.0050,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00047: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00047: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00047_47_batch_size=4096,dropout=0.3000,lr=0.0050,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00048: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00048: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00048_48_batch_size=512,dropout=0.0000,lr=0.0010,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00049: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00049: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00049_49_batch_size=1024,dropout=0.0000,lr=0.0010,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00050: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00050: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00050_50_batch_size=2048,dropout=0.0000,lr=0.0010,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00051: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00051: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00051_51_batch_size=4096,dropout=0.0000,lr=0.0010,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00052: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00052: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00052_52_batch_size=512,dropout=0.1000,lr=0.0010,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00053: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00053: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00053_53_batch_size=1024,dropout=0.1000,lr=0.0010,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00054: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00054: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00054_54_batch_size=2048,dropout=0.1000,lr=0.0010,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00055: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00055: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00055_55_batch_size=4096,dropout=0.1000,lr=0.0010,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00056: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00056: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00056_56_batch_size=512,dropout=0.1500,lr=0.0010,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00057: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00057: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00057_57_batch_size=1024,dropout=0.1500,lr=0.0010,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00058: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00058: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00058_58_batch_size=2048,dropout=0.1500,lr=0.0010,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00059: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00059: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00059_59_batch_size=4096,dropout=0.1500,lr=0.0010,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00060: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00060: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00060_60_batch_size=512,dropout=0.2000,lr=0.0010,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00061: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00061: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00061_61_batch_size=1024,dropout=0.2000,lr=0.0010,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00062: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00062: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00062_62_batch_size=2048,dropout=0.2000,lr=0.0010,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00063: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00063: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00063_63_batch_size=4096,dropout=0.2000,lr=0.0010,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00064: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00064: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00064_64_batch_size=512,dropout=0.2500,lr=0.0010,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00065: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00065: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00065_65_batch_size=1024,dropout=0.2500,lr=0.0010,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00066: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00066: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00066_66_batch_size=2048,dropout=0.2500,lr=0.0010,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00067: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00067: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00067_67_batch_size=4096,dropout=0.2500,lr=0.0010,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00068: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00068: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00068_68_batch_size=512,dropout=0.3000,lr=0.0010,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00069: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00069: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00069_69_batch_size=1024,dropout=0.3000,lr=0.0010,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00070: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00070: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00070_70_batch_size=2048,dropout=0.3000,lr=0.0010,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00071: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00071: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00071_71_batch_size=4096,dropout=0.3000,lr=0.0010,mf_dim=4,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00072: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00072: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00072_72_batch_size=512,dropout=0.0000,lr=0.0100,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00073: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00073: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00073_73_batch_size=1024,dropout=0.0000,lr=0.0100,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00074: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00074: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00074_74_batch_size=2048,dropout=0.0000,lr=0.0100,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00075: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00075: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00075_75_batch_size=4096,dropout=0.0000,lr=0.0100,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00076: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00076: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00076_76_batch_size=512,dropout=0.1000,lr=0.0100,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00077: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00077: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00077_77_batch_size=1024,dropout=0.1000,lr=0.0100,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00078: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00078: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00078_78_batch_size=2048,dropout=0.1000,lr=0.0100,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00079: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00079: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00079_79_batch_size=4096,dropout=0.1000,lr=0.0100,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00080: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00080: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00080_80_batch_size=512,dropout=0.1500,lr=0.0100,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00081: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00081: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00081_81_batch_size=1024,dropout=0.1500,lr=0.0100,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00082: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00082: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00082_82_batch_size=2048,dropout=0.1500,lr=0.0100,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00083: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00083: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00083_83_batch_size=4096,dropout=0.1500,lr=0.0100,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00084: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00084: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00084_84_batch_size=512,dropout=0.2000,lr=0.0100,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00085: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00085: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00085_85_batch_size=1024,dropout=0.2000,lr=0.0100,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00086: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00086: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00086_86_batch_size=2048,dropout=0.2000,lr=0.0100,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00087: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00087: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00087_87_batch_size=4096,dropout=0.2000,lr=0.0100,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00088: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00088: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00088_88_batch_size=512,dropout=0.2500,lr=0.0100,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00089: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00089: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00089_89_batch_size=1024,dropout=0.2500,lr=0.0100,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00090: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00090: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00090_90_batch_size=2048,dropout=0.2500,lr=0.0100,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00091: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00091: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00091_91_batch_size=4096,dropout=0.2500,lr=0.0100,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00092: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00092: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00092_92_batch_size=512,dropout=0.3000,lr=0.0100,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00093: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00093: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00093_93_batch_size=1024,dropout=0.3000,lr=0.0100,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00094: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00094: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00094_94_batch_size=2048,dropout=0.3000,lr=0.0100,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00095: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00095: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00095_95_batch_size=4096,dropout=0.3000,lr=0.0100,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00096: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00096: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00096_96_batch_size=512,dropout=0.0000,lr=0.0050,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00097: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00097: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00097_97_batch_size=1024,dropout=0.0000,lr=0.0050,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00098: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00098: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00098_98_batch_size=2048,dropout=0.0000,lr=0.0050,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00099: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00099: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00099_99_batch_size=4096,dropout=0.0000,lr=0.0050,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00100: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00100: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00100_100_batch_size=512,dropout=0.1000,lr=0.0050,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00101: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00101: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00101_101_batch_size=1024,dropout=0.1000,lr=0.0050,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00102: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00102: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00102_102_batch_size=2048,dropout=0.1000,lr=0.0050,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00103: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00103: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00103_103_batch_size=4096,dropout=0.1000,lr=0.0050,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00104: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00104: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00104_104_batch_size=512,dropout=0.1500,lr=0.0050,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00105: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00105: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00105_105_batch_size=1024,dropout=0.1500,lr=0.0050,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00106: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00106: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00106_106_batch_size=2048,dropout=0.1500,lr=0.0050,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00107: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00107: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00107_107_batch_size=4096,dropout=0.1500,lr=0.0050,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00108: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00108: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00108_108_batch_size=512,dropout=0.2000,lr=0.0050,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00109: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00109: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00109_109_batch_size=1024,dropout=0.2000,lr=0.0050,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00110: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00110: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00110_110_batch_size=2048,dropout=0.2000,lr=0.0050,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00111: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00111: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00111_111_batch_size=4096,dropout=0.2000,lr=0.0050,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00112: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00112: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00112_112_batch_size=512,dropout=0.2500,lr=0.0050,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00113: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00113: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00113_113_batch_size=1024,dropout=0.2500,lr=0.0050,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-13')
# - train_with_k_fold_d8d1b_00114: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00114: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00114_114_batch_size=2048,dropout=0.2500,lr=0.0050,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00115: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00115: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00115_115_batch_size=4096,dropout=0.2500,lr=0.0050,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00116: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00116: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00116_116_batch_size=512,dropout=0.3000,lr=0.0050,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00117: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00117: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00117_117_batch_size=1024,dropout=0.3000,lr=0.0050,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00118: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00118: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00118_118_batch_size=2048,dropout=0.3000,lr=0.0050,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00119: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00119: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00119_119_batch_size=4096,dropout=0.3000,lr=0.0050,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00120: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00120: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00120_120_batch_size=512,dropout=0.0000,lr=0.0010,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00121: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00121: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00121_121_batch_size=1024,dropout=0.0000,lr=0.0010,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00122: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00122: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00122_122_batch_size=2048,dropout=0.0000,lr=0.0010,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00123: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00123: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00123_123_batch_size=4096,dropout=0.0000,lr=0.0010,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00124: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00124: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00124_124_batch_size=512,dropout=0.1000,lr=0.0010,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00125: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00125: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00125_125_batch_size=1024,dropout=0.1000,lr=0.0010,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00126: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00126: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00126_126_batch_size=2048,dropout=0.1000,lr=0.0010,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00127: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00127: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00127_127_batch_size=4096,dropout=0.1000,lr=0.0010,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00128: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00128: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00128_128_batch_size=512,dropout=0.1500,lr=0.0010,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00129: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00129: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00129_129_batch_size=1024,dropout=0.1500,lr=0.0010,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00130: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00130: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00130_130_batch_size=2048,dropout=0.1500,lr=0.0010,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00131: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00131: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00131_131_batch_size=4096,dropout=0.1500,lr=0.0010,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00132: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00132: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00132_132_batch_size=512,dropout=0.2000,lr=0.0010,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00133: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00133: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00133_133_batch_size=1024,dropout=0.2000,lr=0.0010,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00134: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00134: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00134_134_batch_size=2048,dropout=0.2000,lr=0.0010,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00135: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00135: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00135_135_batch_size=4096,dropout=0.2000,lr=0.0010,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00136: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00136: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00136_136_batch_size=512,dropout=0.2500,lr=0.0010,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00137: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00137: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00137_137_batch_size=1024,dropout=0.2500,lr=0.0010,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00138: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00138: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00138_138_batch_size=2048,dropout=0.2500,lr=0.0010,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00139: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00139: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00139_139_batch_size=4096,dropout=0.2500,lr=0.0010,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00140: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00140: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00140_140_batch_size=512,dropout=0.3000,lr=0.0010,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00141: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00141: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00141_141_batch_size=1024,dropout=0.3000,lr=0.0010,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00142: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00142: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00142_142_batch_size=2048,dropout=0.3000,lr=0.0010,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00143: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00143: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00143_143_batch_size=4096,dropout=0.3000,lr=0.0010,mf_dim=8,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00144: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00144: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00144_144_batch_size=512,dropout=0.0000,lr=0.0100,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00145: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00145: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00145_145_batch_size=1024,dropout=0.0000,lr=0.0100,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00146: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00146: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00146_146_batch_size=2048,dropout=0.0000,lr=0.0100,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00147: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00147: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00147_147_batch_size=4096,dropout=0.0000,lr=0.0100,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00148: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00148: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00148_148_batch_size=512,dropout=0.1000,lr=0.0100,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# ...
# - train_with_k_fold_d8d1b_00180: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00180: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00180_180_batch_size=512,dropout=0.2000,lr=0.0050,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00181: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00181: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00181_181_batch_size=1024,dropout=0.2000,lr=0.0050,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00182: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00182: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00182_182_batch_size=2048,dropout=0.2000,lr=0.0050,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00183: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00183: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00183_183_batch_size=4096,dropout=0.2000,lr=0.0050,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00184: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00184: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00184_184_batch_size=512,dropout=0.2500,lr=0.0050,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00185: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00185: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00185_185_batch_size=1024,dropout=0.2500,lr=0.0050,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00186: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00186: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00186_186_batch_size=2048,dropout=0.2500,lr=0.0050,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00187: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00187: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00187_187_batch_size=4096,dropout=0.2500,lr=0.0050,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00188: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00188: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00188_188_batch_size=512,dropout=0.3000,lr=0.0050,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00189: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00189: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00189_189_batch_size=1024,dropout=0.3000,lr=0.0050,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00190: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00190: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00190_190_batch_size=2048,dropout=0.3000,lr=0.0050,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00191: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00191: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00191_191_batch_size=4096,dropout=0.3000,lr=0.0050,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00192: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00192: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00192_192_batch_size=512,dropout=0.0000,lr=0.0010,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00193: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00193: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00193_193_batch_size=1024,dropout=0.0000,lr=0.0010,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00194: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00194: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00194_194_batch_size=2048,dropout=0.0000,lr=0.0010,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00195: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00195: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00195_195_batch_size=4096,dropout=0.0000,lr=0.0010,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00196: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00196: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00196_196_batch_size=512,dropout=0.1000,lr=0.0010,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00197: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00197: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00197_197_batch_size=1024,dropout=0.1000,lr=0.0010,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00198: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00198: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00198_198_batch_size=2048,dropout=0.1000,lr=0.0010,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00199: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00199: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00199_199_batch_size=4096,dropout=0.1000,lr=0.0010,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-14')
# - train_with_k_fold_d8d1b_00200: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00200: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00200_200_batch_size=512,dropout=0.1500,lr=0.0010,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-18')
# - train_with_k_fold_d8d1b_00201: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00201: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00201_201_batch_size=1024,dropout=0.1500,lr=0.0010,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-18')
# - train_with_k_fold_d8d1b_00202: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00202: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00202_202_batch_size=2048,dropout=0.1500,lr=0.0010,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-18')
# - train_with_k_fold_d8d1b_00203: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00203: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00203_203_batch_size=4096,dropout=0.1500,lr=0.0010,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-18')
# - train_with_k_fold_d8d1b_00204: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00204: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00204_204_batch_size=512,dropout=0.2000,lr=0.0010,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-18')
# - train_with_k_fold_d8d1b_00205: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00205: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00205_205_batch_size=1024,dropout=0.2000,lr=0.0010,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-18')
# - train_with_k_fold_d8d1b_00206: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00206: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00206_206_batch_size=2048,dropout=0.2000,lr=0.0010,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-18')
# - train_with_k_fold_d8d1b_00207: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00207: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00207_207_batch_size=4096,dropout=0.2000,lr=0.0010,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-18')
# - train_with_k_fold_d8d1b_00208: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00208: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00208_208_batch_size=512,dropout=0.2500,lr=0.0010,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-18')
# - train_with_k_fold_d8d1b_00209: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00209: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00209_209_batch_size=1024,dropout=0.2500,lr=0.0010,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-18')
# - train_with_k_fold_d8d1b_00210: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00210: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00210_210_batch_size=2048,dropout=0.2500,lr=0.0010,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-40')
# - train_with_k_fold_d8d1b_00211: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00211: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00211_211_batch_size=4096,dropout=0.2500,lr=0.0010,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-40')
# - train_with_k_fold_d8d1b_00212: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00212: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00212_212_batch_size=512,dropout=0.3000,lr=0.0010,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-42')
# - train_with_k_fold_d8d1b_00213: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00213: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00213_213_batch_size=1024,dropout=0.3000,lr=0.0010,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-42')
# - train_with_k_fold_d8d1b_00214: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00214: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00214_214_batch_size=2048,dropout=0.3000,lr=0.0010,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-47')
# - train_with_k_fold_d8d1b_00215: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00215: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00215_215_batch_size=4096,dropout=0.3000,lr=0.0010,mf_dim=16,mlp_layers=8_4,weight_decay=0.0010_2024-12-10_18-26-48')
# - train_with_k_fold_d8d1b_00216: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00216: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00216_216_batch_size=512,dropout=0.0000,lr=0.0100,mf_dim=4,mlp_layers=16_4,weight_decay=0.0010_2024-12-10_18-26-54')
# - train_with_k_fold_d8d1b_00217: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00217: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00217_217_batch_size=1024,dropout=0.0000,lr=0.0100,mf_dim=4,mlp_layers=16_4,weight_decay=0.0010_2024-12-10_18-27-07')
# - train_with_k_fold_d8d1b_00218: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00218: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00218_218_batch_size=2048,dropout=0.0000,lr=0.0100,mf_dim=4,mlp_layers=16_4,weight_decay=0.0010_2024-12-10_18-27-07')
# - train_with_k_fold_d8d1b_00219: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00219: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00219_219_batch_size=4096,dropout=0.0000,lr=0.0100,mf_dim=4,mlp_layers=16_4,weight_decay=0.0010_2024-12-10_18-27-22')
# - train_with_k_fold_d8d1b_00220: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00220: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00220_220_batch_size=512,dropout=0.1000,lr=0.0100,mf_dim=4,mlp_layers=16_4,weight_decay=0.0010_2024-12-10_18-27-28')
# - train_with_k_fold_d8d1b_00221: FileNotFoundError('Could not fetch metrics for train_with_k_fold_d8d1b_00221: both result.json and progress.csv were not found at /Users/aryanahadinia/ray_results/train_with_k_fold_2024-12-10_18-26-10/train_with_k_fold_d8d1b_00221_221_batch_size=1024,dropout=0.1000,lr=0.0100,mf_dim=4,mlp_layers=16_4,weight_decay=0.0010_2024-12-10_18-27-29')
# Best config found: {'mf_dim': 4, 'mlp_layers': [8, 4], 'dropout': 0.0, 'lr': 0.01, 'weight_decay': 0.001, 'batch_size': 4096}
# (train_with_k_fold pid=84666) using cpu
