# %%
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
root = Path("./results")

# %%
svd_results = pd.read_csv(root / "svd_results.csv")
svd_results = svd_results.sort_values("rank_test_rmse")
svd_results[["mean_test_rmse", "std_test_rmse", "mean_test_mae", "std_test_mae", "rank_test_rmse", "rank_test_mae", "params"]]
# Out:
#      mean_test_rmse  std_test_rmse  mean_test_mae  std_test_mae  \
# 4          0.890102       0.005111       0.680302      0.004469
# 5          0.890169       0.005227       0.681140      0.004566
# 3          0.890187       0.005083       0.679452      0.004359
# 14         0.890276       0.005220       0.681091      0.004481
# 41         0.890316       0.005186       0.681115      0.004475
# ..              ...            ...            ...           ...
# 51         0.899074       0.004811       0.685476      0.003965
# 78         0.900305       0.004575       0.686039      0.003811
# 105        0.900797       0.005721       0.687122      0.004410
# 132        0.900987       0.005318       0.687254      0.004500
# 159        0.901092       0.005373       0.687915      0.004437
#
#      rank_test_rmse  rank_test_mae  \
# 4                 1              9
# 5                 2             28
# 3                 3              1
# 14                4             25
# ...

# %%
svd_pp_results = pd.read_csv(root / "svd++_results.csv")
svd_pp_results = svd_pp_results.sort_values("rank_test_rmse")
svd_pp_results[["mean_test_rmse", "std_test_rmse", "mean_test_mae", "std_test_mae", "rank_test_rmse", "rank_test_mae", "params"]]
# Out:
#      mean_test_rmse  std_test_rmse  mean_test_mae  std_test_mae  \
# 4          0.891002       0.004127       0.680744      0.002812
# 14         0.891035       0.004282       0.681445      0.003130
# 5          0.891224       0.004170       0.681562      0.002986
# 3          0.891494       0.004311       0.680049      0.003039
# 13         0.891559       0.003712       0.681031      0.002642
# ..              ...            ...            ...           ...
# 160        0.915346       0.004563       0.698452      0.003827
# 150        0.916216       0.004062       0.698551      0.003452
# 105        0.916869       0.003727       0.698711      0.002794
# 132        0.917567       0.004578       0.700026      0.003422
# 159        0.919550       0.003760       0.701842      0.003358
#
#      rank_test_rmse  rank_test_mae  \
# 4                 1              2
# 14                2              6
# 5                 3              7
# 3                 4              1
# ...

# %%
nmf_results = pd.read_csv(root / "nmf_results.csv")
nmf_results = nmf_results.sort_values("rank_test_rmse")
nmf_results[["mean_test_rmse", "std_test_rmse", "mean_test_mae", "std_test_mae", "rank_test_rmse", "rank_test_mae", "params"]]
# Out:
#     mean_test_rmse  std_test_rmse  mean_test_mae  std_test_mae  \
# 4         0.978206       0.004147       0.746760      0.003702
# 2         0.978254       0.003747       0.749443      0.003384
# 0         0.980802       0.003667       0.757589      0.002713
# 8         0.988009       0.004476       0.755287      0.003117
# 10        0.988827       0.003448       0.753341      0.002902
# 6         0.989366       0.004416       0.761776      0.003148
# 14        0.993166       0.003911       0.757973      0.003447
# 12        0.993739       0.003698       0.763605      0.003042
# 16        0.994210       0.004489       0.756481      0.003729
# 18        0.996970       0.004574       0.765247      0.003375
# 20        0.997092       0.004901       0.760142      0.004130
# 22        0.997629       0.003518       0.758093      0.003141
# 26        0.999433       0.003957       0.761014      0.002909
# 24        0.999490       0.004159       0.765964      0.003220
# ...

# %%
knn_basic_results = pd.read_csv(root / "knn_basic_results.csv")
knn_basic_results = knn_basic_results.sort_values("rank_test_rmse")
knn_basic_results[["mean_test_rmse", "std_test_rmse", "mean_test_mae", "std_test_mae", "rank_test_rmse", "rank_test_mae", "params"]]
# Out:
#     mean_test_rmse  std_test_rmse  mean_test_mae  std_test_mae  \
# 71        1.076547       0.003552       0.806736      0.002147
# 41        1.076623       0.003583       0.806835      0.002126
# 11        1.076922       0.003580       0.807197      0.002126
# 31        1.077542       0.004041       0.806322      0.002624
# 61        1.077559       0.004037       0.806364      0.002618
# ..             ...            ...            ...           ...
# 42        1.152801       0.003847       0.914890      0.003809
# 72        1.152801       0.003848       0.914890      0.003814
# 70        1.153014       0.005109       0.904837      0.004768
# 40        1.153016       0.005110       0.904842      0.004766
# 10        1.153106       0.005171       0.904937      0.004821
#
#     rank_test_rmse  rank_test_mae  \
# 71               1              4
# 41               2              5
# 11               3              6
# 31               4              1
# ...

# %%
knn_with_means_results = pd.read_csv(root / "knn_with_means_results.csv")
knn_with_means_results = knn_with_means_results.sort_values("rank_test_rmse")
knn_with_means_results[["mean_test_rmse", "std_test_rmse", "mean_test_mae", "std_test_mae", "rank_test_rmse", "rank_test_mae", "params"]]
# Out:
#     mean_test_rmse  std_test_rmse  mean_test_mae  std_test_mae  \
# 88        1.020588       0.002362       0.759528      0.001455
# 58        1.020589       0.002361       0.759528      0.001455
# 28        1.020590       0.002359       0.759529      0.001454
# 86        1.023730       0.003058       0.761998      0.001842
# 56        1.023730       0.003058       0.761998      0.001842
# ..             ...            ...            ...           ...
# 79        1.081835       0.001472       0.836623      0.001114
# 49        1.081835       0.001472       0.836623      0.001114
# 9         1.081881       0.001438       0.836633      0.001055
# 69        1.081882       0.001438       0.836633      0.001055
# 39        1.081882       0.001438       0.836633      0.001055
#
#     rank_test_rmse  rank_test_mae  \
# 88               1              1
# 58               2              2
# 28               3              3
# 86               4              4
# ...

# %%
knn_with_z_score_results_df = pd.read_csv(root / "knn_with_z_score_results.csv")
knn_with_z_score_results_df = knn_with_z_score_results_df.sort_values("rank_test_rmse")
knn_with_z_score_results_df[["mean_test_rmse", "std_test_rmse", "mean_test_mae", "std_test_mae", "rank_test_rmse", "rank_test_mae", "params"]]

# %%
knn_baseline_results_df = pd.read_csv(root / "knn_baseline_results.csv")
knn_baseline_results_df = knn_baseline_results_df.sort_values("rank_test_rmse")
knn_baseline_results_df[["mean_test_rmse", "std_test_rmse", "mean_test_mae", "std_test_mae", "rank_test_rmse", "rank_test_mae", "params"]]
